# %%
import pandas as pd
import numpy as np

df=pd.read_csv('./new_data.csv',encoding= 'euc-kr', index_col= 0)
df
# Out:
#         달러원종가    달러원시가  CD91   WTI가   달러위안화     달러엔     달러인덱스   유로인덱스    콜금리  \
# 0     1150.00  1164.07  2.88  81.64  6.8285   92.47   92.3566  106.23  1.980
# 1     1140.20  1151.00  2.88  81.47  6.8268   91.58   92.2236  105.82  1.980
# 2     1129.20  1140.20  2.88  83.25  6.8278   92.38   92.0941  106.11  1.960
# 3     1138.20  1129.20  2.88  82.69  6.8281   93.45   92.3684  105.84  1.990
# 4     1128.25  1135.50  2.88  82.91  6.8276   92.68   92.1485  106.18  2.000
# ...       ...      ...   ...    ...     ...     ...       ...     ...    ...
# 3313  1325.49  1336.34  3.72  87.42  7.2882  146.58  121.8185  124.19  3.602
# 3314  1326.15  1326.05  3.73  88.94  7.2910  147.08  121.7721  124.21  3.597
# 3315  1326.59  1326.72  3.75  88.80  7.2700  147.45  121.5454  124.25  3.592
# 3316  1329.52  1328.20  3.76  90.67  7.2770  147.47  121.7192  124.19  3.587
# 3317  1328.46  1330.02  3.78  91.15  7.2744  147.82  121.6815  123.94  3.580
#
#             코스피종가   BIR  target
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge,Lasso,LinearRegression,SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,r2_score

# %%
# 데이터 전처리 
X = df[[ '달러위안화', '달러엔', '달러인덱스', '유로인덱스','BIR']]
y= df[['달러원종가']]

# 데이터를 훈련 세트와 테스트 세트로 분할
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# 파이프라인 생성
pipeline = Pipeline([
    ('std_scaler', StandardScaler()),  # 표준화
    ('ridge_reg', Ridge(alpha=1, solver="cholesky"))
])

# 파이프라인 학습
pipeline.fit(X_train, y_train)

# 예측 및 성능 평가
y_pred = pipeline.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
score = r2_score(y_pred,y_test)


print(f'Mean Squared Error: {mse:.2f}')
print(f'Root Mean Squared Error: {rmse:.2f}')
print(f'r2_score:{score:.2f}')
# Out:
# Mean Squared Error: 2084.29
# Root Mean Squared Error: 45.65
# r2_score:0.42

# %% [markdown]
# ---

# %% [markdown]
# <https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html>

# %% [markdown]
# ---

# %% [markdown]
# Linear Model trained with L1 prior as regularizer (aka the Lasso).
#
# The optimization objective for Lasso is:

# %% [markdown]
# ---
# - 번역

# %% [markdown]
# 정규화 도구(일명 Lasso)로서 사전에 L1을 사용하여 훈련된 선형 모델입니다.
#
# Lasso의 최적화 목표는 다음과 같습니다.
#
# (1 / (2 * n_samples)) * ||y - Xw||^2_2 + alpha * ||w||_1
# 기술적으로 Lasso 모델은 l1_ratio=1.0L2 페널티 없이 Elastic Net과 동일한 목적 함수를 최적화합니다.
#
# 사용자 가이드 에서 자세한 내용을 읽어보세요 .

# %% [markdown]
# ### 오류 이유

# %% [markdown]
# 1. 파이프라인안에 스탭 사이에 ,를 빼먹었다
# 2. Ridge,Lasso 의 사용법을 몰랐다
#     - 공식문서 보고 번역해서 파일 만들어 놓으세요
